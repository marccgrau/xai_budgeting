# %%
import pandas as pd

# %% [markdown]
# ### 2013 source file spec

# %%
# Define the file path
file_path = r'C:\Users\domin\Documents\GitHub\xai_budgeting\data\raw\kdkf_2013_raw.xlsx'

# Load the Excel file to get sheet names
xls = pd.ExcelFile(file_path)

# Define the years
previous_year = 2012
start_year = 2013
target_year = 2014

# Set the pandas option to display floating point numbers using the decimal format
pd.options.display.float_format = '{:.5f}'.format

# %% [markdown]
# ### Master Loop

# %%
# Initialize an empty DataFrame for the master data
master_2013 = pd.DataFrame()

# Loop over each sheet in the Excel file
for sheet_name in xls.sheet_names:
    # Check if the sheet name starts with "HRM2_KT_"
    if sheet_name.endswith("HRM2"):
        # Load the sheet into a DataFrame, skipping the first three rows
        df = pd.read_excel(file_path, sheet_name=sheet_name, skiprows=0)

        # Merge the first row with the column headers
        df.columns = df.iloc[0, :2].tolist() + (df.columns[2:]).tolist()
        df = df.iloc[1:].reset_index(drop=True)

        # Update Headers of the df
        rename_dict = {
            'Rechnung': f'Rechnung {previous_year}',
            'Budget': f'Budget {start_year}',
            'Rechnung.1': f'Rechnung {start_year}',
            'Budget.1': f'Budget {target_year}'
        }
        df.rename(columns=rename_dict, inplace=True)

        # Rename the first column to 'HRM 2' and third column to "in 1000 CHF"
        df.columns.values[0] = 'HRM2-ID'
        df.columns.values[2] = 'HRM2-Bezeichnung'

        # Delete unecessary columns
        df.drop(df.columns[1], axis=1, inplace=True)
             
        # Add a new column with the DataFrame name (sheet name)
        df['Source'] = sheet_name
        df['Kanton'] = df['Source'].str.split(' HRM2').str[0]
        df['Year'] = 2013

        # Use pd.concat to add the DataFrame to the master DataFrame
        master_2013 = pd.concat([master_2013, df], ignore_index=True)

# Display the first few rows of the master DataFrame
master_2013.head()
# Out:
#            HRM2-ID                       HRM2-Bezeichnung Rechnung 2012  \
# 0  ERFOLGSRECHNUNG                                    NaN           NaN
# 1               30                        Personalaufwand 4782409.41000
# 2               31      Sach- und übriger Betriebsaufwand 2742025.90000
# 3        davon 314  baulicher und betrieblicher Unterhalt  194592.14000
# 4       davon 3180     Wertberichtigungen auf Forderungen  -15285.00000
#
#     Budget 2013 Rechnung 2013   Budget 2014   Source Kanton  Year  Compte  \
# 0          def.           NaN           NaN  ZH HRM2     ZH  2013     NaN
# 1 4827007.19000 4727960.22320 4944121.85400  ZH HRM2     ZH  2013     NaN
# 2 2633519.28000 2856763.26085 2972686.19200  ZH HRM2     ZH  2013     NaN
# 3  202593.45000  207716.98300  213736.65000  ZH HRM2     ZH  2013     NaN
# 4    3557.70000    3809.96198     916.60000  ZH HRM2     ZH  2013     NaN
#
#    Compte.1
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %% [markdown]
# ### Translating FR columns to DE

# %%
# Display rows where the column 'Kanton' is 'FR HRM2'
filtered_rows = master_2013[master_2013['Kanton'] == 'FR']

# Display the filtered rows
filtered_rows.head()
# Out:
#                   HRM2-ID                                   HRM2-Bezeichnung  \
# 1288  Compte de résultats                                                NaN
# 1289                   30                               Charges de personnel
# 1290                   31  Charges de biens et services et autres charges...
# 1291          de cela 314                Gros entretien et entretien courant
# 1292         de cela 3180                         Réévaluations sur créances
#
#      Rechnung 2012   Budget 2013 Rechnung 2013 Budget 2014   Source Kanton  \
# 1288           NaN          def.           NaN        def.  FR HRM2     FR
# 1289           NaN 1173958.40000           NaN     1174614  FR HRM2     FR
# 1290           NaN        323472           NaN      323144  FR HRM2     FR
# 1291           NaN           NaN           NaN       43868  FR HRM2     FR
# 1292           NaN           NaN           NaN           0  FR HRM2     FR
#
#       Year        Compte      Compte.1
# 1288  2013           NaN           NaN
# 1289  2013 1158331.90000 1179831.00000
# 1290  2013  318554.00000  319170.00000
# 1291  2013   49697.80000   45853.00000
# 1292  2013   13764.40000    2331.00000

# %%
# 1. Update 'Rechnung 2012' based on 'Compte'
master_2013['Rechnung 2012'] = master_2013.apply(
    lambda row: row['Compte'] if pd.isna(row['Rechnung 2012']) and not pd.isna(row['Compte']) else row['Rechnung 2012'],
    axis=1
)

# 2. Update 'Rechnung 2013' based on 'Compte.1'
master_2013['Rechnung 2013'] = master_2013.apply(
    lambda row: row['Compte.1'] if pd.isna(row['Rechnung 2013']) and not pd.isna(row['Compte.1']) else row['Rechnung 2013'],
    axis=1
)

# Display the first few rows of the updated DataFrame
master_2013.head()
# Out:
#            HRM2-ID                       HRM2-Bezeichnung Rechnung 2012  \
# 0  ERFOLGSRECHNUNG                                    NaN           NaN
# 1               30                        Personalaufwand 4782409.41000
# 2               31      Sach- und übriger Betriebsaufwand 2742025.90000
# 3        davon 314  baulicher und betrieblicher Unterhalt  194592.14000
# 4       davon 3180     Wertberichtigungen auf Forderungen  -15285.00000
#
#     Budget 2013 Rechnung 2013   Budget 2014   Source Kanton  Year  Compte  \
# 0          def.           NaN           NaN  ZH HRM2     ZH  2013     NaN
# 1 4827007.19000 4727960.22320 4944121.85400  ZH HRM2     ZH  2013     NaN
# 2 2633519.28000 2856763.26085 2972686.19200  ZH HRM2     ZH  2013     NaN
# 3  202593.45000  207716.98300  213736.65000  ZH HRM2     ZH  2013     NaN
# 4    3557.70000    3809.96198     916.60000  ZH HRM2     ZH  2013     NaN
#
#    Compte.1
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
# Display rows where the column 'Kanton' is 'VD_HRM2'
filtered_rows = master_2013[master_2013['Kanton'] == 'FR']

# Display the filtered rows
filtered_rows.head()
# Out:
#      HRM2-ID                                   HRM2-Bezeichnung Rechnung 2012  \
# 1289      30                               Charges de personnel 1158331.90000
# 1290      31  Charges de biens et services et autres charges...  318554.00000
# 1293     330                  Immobilisations corporelles du PA   61027.60000
# 1294     332   Amortissements des immobilisations incorporelles           NaN
# 1295     339                Remboursement du découvert du bilan       0.00000
#
#        Budget 2013 Rechnung 2013 Budget 2014   Source Kanton  Year  \
# 1289 1173958.40000 1179831.00000     1174614  FR HRM2     FR  2013
# 1290        323472  319170.00000      323144  FR HRM2     FR  2013
# 1293         66129   64408.00000       78570  FR HRM2     FR  2013
# 1294           NaN           NaN         NaN  FR HRM2     FR  2013
# 1295           NaN           NaN         NaN  FR HRM2     FR  2013
#
#             Compte      Compte.1
# 1289 1158331.90000 1179831.00000
# 1290  318554.00000  319170.00000
# 1293   61027.60000   64408.00000
# 1294           NaN           NaN
# 1295       0.00000           NaN

# %% [markdown]
# ### Before saving the data, we drop non-numeric "HRM2-IDs", because they would cause issues with subsequent automated analysis...

# %%
# Drop rows where 'HRM-ID' values are non-numeric
master_2013 = master_2013[pd.to_numeric(master_2013['HRM2-ID'], errors='coerce').notna()]

# Display the first few rows of the updated DataFrame
len(master_2013)
# Out:
# 1664

# %%
# Define the path where the CSV file will be saved
output_path = r'C:\Users\domin\Documents\GitHub\xai_budgeting\data\ready\kdkf_2013_data.csv'

# Save the DataFrame to a CSV file
master_2013.to_csv(output_path, index=False)
